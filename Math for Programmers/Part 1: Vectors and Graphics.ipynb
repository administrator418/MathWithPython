# %% [markdown]
# # Part 1: Vectors and Graphics

# %% [markdown]
# ## 1.0.1 Data Analysis with Python
#
# numpy: https://numpy.org/doc/stable/
# matplotlib: https://matplotlib.org/stable/index.html
# pandas: https://pandas.pydata.org/docs/

# %% [markdown]
# ## 1.0.1 几个基本概念
#
# vector(向量)
#
# linear transformation(线性变换):线性变换是一种函数，将一个向量作为输入并返回一个向量作为输出，同时保持所操作向量（在特殊意义上）的几何形状。例如，如果一个向量（点）的集合位于二维平面的一条直线上，在应用线性变换后，它们仍然会位于一条直线上。
#
# matrix(矩阵):矩阵是一种可以表示线性变换的矩形数组。
#
# vector space(向量空间)
#
# dimension(维度)
#
# system of linear equations(线性方程组)

# %% [markdown]
# ## 1.1 二维向量绘图

# %% [markdown]
# 二维向量一个点相较于原点的位置，可以表示两点之间的位置关系。编程中常常使用[x, y]表示一个二维向量。

# %% [markdown]
# 下面使用matplotlib画箭头和线

# %%
import matplotlib.pyplot as plt
import numpy as np

# 创建一个画布和坐标轴
fig, ax = plt.subplots()

# 画一条线
ax.plot([1, 2, 3, 4], [1, 4, 2, 3], color='blue')

# 画一个箭头
# x, y 是箭头的起点坐标
# dx, dy 是箭头的长度和方向(可以理解为起点坐标当作原点，箭头的终点坐标是原点加上 dx, dy)
# head_width, head_length 是箭头的宽度和长度
# fc, ec 是箭头的填充颜色和边框颜色
ax.arrow(x=4, y=3, dx=2, dy=1, head_width=0.1, head_length=0.1, fc='red', ec='red')

# 设置坐标轴的范围
ax.set_xlim(0, 10)
ax.set_ylim(0, 10)

# 使用 numpy 生成间隔相等的刻度
ax.set_xticks(np.arange(0, 11, 1))
ax.set_yticks(np.arange(0, 11, 1))

# 显示图形
plt.show()
